# %%
#### STEP:1 IMPORTING THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#### STEP:2 ----LOADING THE FILES
df=pd.read_csv("housing_prices.csv")
df
# Out:
#      Location  Area_sqft  Bedrooms  Bathrooms  Parking  Age_years  Price_Lakhs
# 0      Mumbai        850         2          2        1         10          120
# 1       Delhi        900         3          2        1          8           95
# 2   Bangalore       1100         3          2        1          5           85
# 3   Hyderabad       1050         2          2        1          6           78
# 4     Chennai        950         2          2        1         12           70
# 5        Pune       1000         3          2        1          4           88
# 6     Kolkata        880         2          1        0         15           55
# 7   Ahmedabad        980         2          2        1          7           60
# 8      Jaipur        920         2          2        1          9           58
# 9  Chandigarh       1020         3          2        1          3           90

# %%
#### STEP::3 ----BASIC DATA INSPECTION
df.head()
# Out:
#     Location  Area_sqft  Bedrooms  Bathrooms  Parking  Age_years  Price_Lakhs
# 0     Mumbai        850         2          2        1         10          120
# 1      Delhi        900         3          2        1          8           95
# 2  Bangalore       1100         3          2        1          5           85
# 3  Hyderabad       1050         2          2        1          6           78
# 4    Chennai        950         2          2        1         12           70

# %%
###STEP:3 ----BASIC DATA INSPECTION
df.tail()
# Out:
#      Location  Area_sqft  Bedrooms  Bathrooms  Parking  Age_years  Price_Lakhs
# 5        Pune       1000         3          2        1          4           88
# 6     Kolkata        880         2          1        0         15           55
# 7   Ahmedabad        980         2          2        1          7           60
# 8      Jaipur        920         2          2        1          9           58
# 9  Chandigarh       1020         3          2        1          3           90

# %%
df.shape
# Out:
# (10, 7)

# %%
df.columns
# Out:
# Index(['Location', 'Area_sqft', 'Bedrooms', 'Bathrooms', 'Parking',
#        'Age_years', 'Price_Lakhs'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Location     10 non-null     object
#  1   Area_sqft    10 non-null     int64
#  2   Bedrooms     10 non-null     int64
#  3   Bathrooms    10 non-null     int64
#  4   Parking      10 non-null     int64
#  5   Age_years    10 non-null     int64
#  6   Price_Lakhs  10 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 692.0+ bytes

# %%
#####----STEP:4 STATISTICAL SUMMARY
## explains  *mean vs meadian  *min/max  *standard deviation
df.describe()
# Out:
#         Area_sqft   Bedrooms  Bathrooms    Parking  Age_years  Price_Lakhs
# count    10.00000  10.000000  10.000000  10.000000  10.000000    10.000000
# mean    965.00000   2.400000   1.900000   0.900000   7.900000    79.900000
# std      79.47746   0.516398   0.316228   0.316228   3.725289    20.074583
# min     850.00000   2.000000   1.000000   0.000000   3.000000    55.000000
# 25%     905.00000   2.000000   2.000000   1.000000   5.250000    62.500000
# 50%     965.00000   2.000000   2.000000   1.000000   7.500000    81.500000
# 75%    1015.00000   3.000000   2.000000   1.000000   9.750000    89.500000
# max    1100.00000   3.000000   2.000000   1.000000  15.000000   120.000000

# %%
### STEP:5 CHECK MISSING VALUES(data preprocessing)
## * which column has missing data?
## * how should it be handled?
df.isnull().sum()
# Out:
# Location       0
# Area_sqft      0
# Bedrooms       0
# Bathrooms      0
# Parking        0
# Age_years      0
# Price_Lakhs    0
# dtype: int64

# %%
### STEP :6 UNIVARIETE ANALYSIS
# 6.1 HISTOGRAM(dISTRIBUTION)
plt.figure()
plt.hist(df['Price_Lakhs'],bins=60)
plt.title("price distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.hist(df['Price_Lakhs'],bins=30)
plt.title("price distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.hist(df['Price_Lakhs'],bins=10)
plt.title("price distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.hist(df['Price_Lakhs'],bins=20)
plt.title("price distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
###6.2 BEDROOM VS PRICE
##* price generally incrtease with more bedrooms,but the increase is not strictly linear.
df.groupby('Bedrooms')['Price_Lakhs'].mean().plot(kind='bar')
plt.title('Average Price by Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Average Price')
plt.show()

# %%
#bedroom vs price(...by using scatterplot)
plt.figure()
plt.scatter(df["Bedrooms"],df["Price_Lakhs"])
plt.title("Bedrooms vs Price_Lakhs")
plt.xlabel("Bedrooms")
plt.ylabel("Price_Lakhs")
plt.show()

# %%
#### STEP:7 BIVARIATE ANALYSIS
## 7.1 SCATTER PLOT(AREA VS PRICE)
## *positive/negative correlation **linear relationship
plt.figure()
plt.scatter(df['Area_sqft'],df['Price_Lakhs'])
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Area vs Price')
plt.show()

# %%
##### 7.2 BAR PLOT(LOCATION VS AVG PRICE)
#* Location impact
#*why grouping is important

df.groupby('Location')['Price_Lakhs'].mean().plot(kind='bar')
plt.title("Average Price By Location")
plt.xlabel("Location")
plt.ylabel("Average Price")
plt.show()

# %%
#### STEP:8 --MULTIVARIATE ANALYSIS
# 8.1 CORRELATION Matrix
corr=df.corr(numeric_only=True)
corr
# Out:
#              Area_sqft  Bedrooms  Bathrooms   Parking  Age_years  Price_Lakhs
# Area_sqft     1.000000  0.433161   0.375779  0.375779  -0.726164    -0.088793
# Bedrooms      0.433161  1.000000   0.272166  0.272166  -0.669994     0.411583
# Bathrooms     0.375779  0.272166   1.000000  1.000000  -0.669662     0.435823
# Parking       0.375779  0.272166   1.000000  1.000000  -0.669662     0.435823
# Age_years    -0.726164 -0.669994  -0.669662 -0.669662   1.000000    -0.341875
# Price_Lakhs  -0.088793  0.411583   0.435823  0.435823  -0.341875     1.000000

# %%
#### STEP:8 --MULTIVARIATE ANALYSIS
# 8.2 Heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr,annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
###STEP:8 FEATURE-LEVEL CONCLUSION
#most important feature:Area
#moderately important:Bedrooms, Bathrooms
#HIghly influential categorical feature: Location

# %%
###STEP:9 SAVE DATASET FOR MODELING(OPTIONAL)
df.to_csv("housing_prices_ready.csv",index=False)

# %%
######-----------PART 2 :HANDS-ON LAB(90 MIN)---------------------------------

# %%
#### STEP:1 IMPORTING THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#### STEP:2 ----LOADING THE FILES
df=pd.read_csv("housing_prices.csv")
df
# Out:
#      Location  Area_sqft  Bedrooms  Bathrooms  Parking  Age_years  Price_Lakhs
# 0      Mumbai        850         2          2        1         10          120
# 1       Delhi        900         3          2        1          8           95
# 2   Bangalore       1100         3          2        1          5           85
# 3   Hyderabad       1050         2          2        1          6           78
# 4     Chennai        950         2          2        1         12           70
# 5        Pune       1000         3          2        1          4           88
# 6     Kolkata        880         2          1        0         15           55
# 7   Ahmedabad        980         2          2        1          7           60
# 8      Jaipur        920         2          2        1          9           58
# 9  Chandigarh       1020         3          2        1          3           90

# %%
###STEP:3 --SELECT THE FEATURE AND TARGET
## SIMPLE LINEAR REGRESSION
x=df[['Area_sqft']]
y=df[['Price_Lakhs']]
x
# Out:
#    Area_sqft
# 0        850
# 1        900
# 2       1100
# 3       1050
# 4        950
# 5       1000
# 6        880
# 7        980
# 8        920
# 9       1020

# %%
y
# Out:
#    Price_Lakhs
# 0          120
# 1           95
# 2           85
# 3           78
# 4           70
# 5           88
# 6           55
# 7           60
# 8           58
# 9           90

# %%
###### STEP-4:TRAIN -TEST-SPLIT
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#    Area_sqft
# 5       1000
# 0        850
# 7        980
# 2       1100
# 9       1020
# 4        950
# 3       1050
# 6        880

# %%
x_test
# Out:
#    Area_sqft
# 8        920
# 1        900

# %%
y_train
# Out:
#    Price_Lakhs
# 5           88
# 0          120
# 7           60
# 2           85
# 9           90
# 4           70
# 3           78
# 6           55

# %%
y_test
# Out:
#    Price_Lakhs
# 8           58
# 1           95

# %%
##### STEP:5 BUILD  SIMPLE LINEAR REGRESSION MODEL
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
###STEP-6:PREDICTION
y_pred=model.predict(x_test)
y_pred
# Out:
# array([[82.39266616],
#        [82.95187166]])

# %%
#### STEP:7 MODEL EVALUVATION
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
r2=r2_score(y_test,y_pred)
print("MAE:",mae)
print("RMSE:",rmse)
print("R2 Score:",r2)
# Out:
# MAE: 18.220397249809018
# RMSE: 19.237457716863666
# R2 Score: -0.08131418380750133

# %%
#### STEP:8  VISUALIZE REGRESSION LINE
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred)
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("SIMPLE LINEAR REGRESSION")
plt.show()

# %%
##### STEP:9 MULTI LINEAR REGRESSION
## FEATURE SELECTION
x=df[['Area_sqft','Bedrooms','Bathrooms']]
y=df['Price_Lakhs']
####-------- Train Model----
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2,random_state=42)
model_multi=LinearRegression()
model_multi.fit(x_train,y_train)
y_pred_multi=model_multi.predict(x_test)
#print(x_train,x_test)
y_pred_multi
# Out:
# array([ 89.25023787, 114.73422138])

# %%
##### STEP:10 EVALUVATE MULTIPLE REGRESSION
print("R2 Score:",r2_score(y_test,y_pred_multi))
print("RMSE:", np.sqrt(mean_squared_error(y_test,y_pred_multi)))
# Out:
# R2 Score: -0.9956418702490979
# RMSE: 26.134429974513576

# %%
####STEP:11 INTERPRET COEFFICIENTS
coeff_df=pd.DataFrame(model_multi.coef_,x.columns,columns=['Coefficient'])
coeff_df
####
# Out:
#            Coefficient
# Area_sqft    -0.193340
# Bedrooms     21.617190
# Bathrooms    41.983825
